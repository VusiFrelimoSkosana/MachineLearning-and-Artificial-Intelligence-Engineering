# %%
import numpy
from cvxopt import matrix
from cvxopt import solvers

Q= matrix(numpy.array([[-5,-3,-5],[-3,-5,-3],[-5,-3,-5]]), tc='d')
P= matrix(numpy.array([1,1,1]), tc='d')
G= matrix(numpy.array([[-1,0,0],[0,-1,0],[0,0,-1]]), tc='d')
h= matrix(numpy.array([0,0,0]), tc='d')
A= matrix(numpy.array([-1,-1,1]), tc='d')
b= matrix(numpy.array([0]),tc='d')

sol =solvers.qp(Q,P,G,h,A,b)

print(sol)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5c29f399a70f> in <module>
#      10 b= matrix(numpy.array([0]),tc='d')
#      11
# ---> 12 sol =solvers.qp(Q,P,G,h,A,b)
#      13
#      14 print(sol)
#
# ~\anaconda3\lib\site-packages\cvxopt\coneprog.py in qp(P, q, G, h, A, b, solver, kktsolver, initvals, **kwargs)
#    4483             'residual as dual infeasibility certificate': dinfres}
#    4484
# -> 4485     return coneqp(P, q, G, h, None, A,  b, initvals, kktsolver = kktsolver, options = options)
#
# ~\anaconda3\lib\site-packages\cvxopt\coneprog.py in coneqp(P, q, G, h, dims, A, b, initvals, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#    1911     if matrixA:
#    1912         if A.typecode != 'd' or A.size[1] != q.size[0]:
# -> 1913             raise TypeError("'A' must be a 'd' matrix with %d columns" \
#    1914                 %q.size[0])
#    1915         def fA(x, y, trans = 'N', alpha = 1.0, beta = 0.0):
#
# TypeError: 'A' must be a 'd' matrix with 3 columns

# %%
import matplotlib as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train.csv')
display(df)

# %% [markdown]
# print(df.shape)

# %%
#churn counts
all_churns= df['churn']
all_states= df['state']


filt = (all_churns=='yes')
df[filt]    
print(all_churns)

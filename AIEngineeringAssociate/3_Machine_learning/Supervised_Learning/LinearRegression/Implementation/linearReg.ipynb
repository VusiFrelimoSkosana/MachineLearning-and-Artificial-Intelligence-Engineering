# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Aug 24 10:44:42 2022
@author: Vusi Skosana

"""

import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from importnb import Notebook
with Notebook():
    from easyAI.linear_model import gradient
    from easyAI.linear_model import predict
    from easyAI.linear_model import intercept
    from easyAI.linear_model import variance_fit
    from easyAI.linear_model import r2_score


df=pd.read_csv('Salary.csv')

display(df)
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# ...

# %%
#The x,y are in the form of a list although they don't seem as such as such at first glance
x= df['YearsExperience']
y=df['Salary']

m=gradient(x,y)         #gradient/ slope
pred=predict(5.5,x,y)   #predicted value
b=intercept(x,y)        #y-intercept
var= variance_fit(x,y)  #variance arounf the fit
r2= r2_score(x,y)       #r2 score

print('The gradient of the slope is: ',m)
print('The predicted value is: ',pred)
print('The y-intercept is: ',b)
print('variance around the fit is: ',var)
print('The r2 score is ', r2)
# Out:
# The gradient of the slope is:  8731.941047062492
# The predicted value is:  76885.20195337519
# The y-intercept is:  28859.526194531478
# variance around the fit is:  35006768.19370178
# The r2 score is  0.9651633106751444

# %%
y_fit= m*x + b

plt.scatter(x,y, label='Scatter plot')
plt.xlabel("Years of Experience")
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience')
plt.plot(x, y_fit, color='red', label='best fit line')
plt.legend()
plt.show()

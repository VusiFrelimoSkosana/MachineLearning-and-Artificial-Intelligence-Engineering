# %%
#Execution of python string

code = "x = 18\ny = x + 2"

loc_var = {}
exec(code, {}, loc_var)

output = loc_var.get("y")
print(output)
# Out:
# 20

# %%
#iteration inside a data structure

user_input="table"

requires_dataframe = any(word in user_input.lower() for word in ["table", "dataframe", "show data", "list"])

print(requires_dataframe)
# Out:
# True
